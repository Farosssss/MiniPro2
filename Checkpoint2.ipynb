# %% [markdown]
# <a href="https://colab.research.google.com/github/Farosssss/MiniPro2/blob/main/Checkpoint2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/GeneralEsportData.csv")
df
# Out:
#                                  Game  ReleaseDate                Genre  \
# 0                      Age of Empires         1997             Strategy
# 1                   Age of Empires II         1999             Strategy
# 2                  Age of Empires III         2005             Strategy
# 3                   Age of Empires IV         2021             Strategy
# 4               Age of Empires Online         2011             Strategy
# ..                                ...          ...                  ...
# 664  Guitar Hero III: Legends of Rock         2007  Music / Rhythm Game
# 665           Guitar Hero: World Tour         2008  Music / Rhythm Game
# 666                   Just Dance 2014         2013  Music / Rhythm Game
# 667                              osu!         2007  Music / Rhythm Game
# 668                      Synth Riders         2018  Music / Rhythm Game
#
#      TotalEarnings  OfflineEarnings  PercentOffline  TotalPlayers  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Game              669 non-null    object
#  1   ReleaseDate       669 non-null    int64
#  2   Genre             669 non-null    object
#  3   TotalEarnings     669 non-null    float64
#  4   OfflineEarnings   669 non-null    float64
#  5   PercentOffline    608 non-null    float64
#  6   TotalPlayers      669 non-null    int64
#  7   TotalTournaments  669 non-null    int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 41.9+ KB

# %%
df.shape
# Out:
# (669, 8)

# %%
df.dtypes
# Out:
# Game                 object
# ReleaseDate           int64
# Genre                object
# TotalEarnings       float64
# OfflineEarnings     float64
# PercentOffline      float64
# TotalPlayers          int64
# TotalTournaments      int64
# dtype: object

# %%
df.describe()
# Out:
#        ReleaseDate  TotalEarnings  OfflineEarnings  PercentOffline  \
# count   669.000000   6.690000e+02     6.690000e+02      608.000000
# mean   2012.786248   2.828053e+06     1.993360e+06        0.658571
# std       7.549283   1.880973e+07     1.454905e+07        0.411090
# min    1981.000000   0.000000e+00     0.000000e+00        0.000000
# 25%    2007.000000   1.174500e+03     0.000000e+00        0.244969
# 50%    2015.000000   3.927973e+04     1.855365e+04        0.906313
# 75%    2019.000000   3.087947e+05     2.125403e+05        1.000000
# max    2025.000000   3.604612e+08     3.135548e+08        1.000000
#
#        TotalPlayers  TotalTournaments
# count    669.000000        669.000000
# mean     247.953662        100.239163
# std     1034.404477        502.815941
# min        0.000000          0.000000
# 25%        5.000000          1.000000
# 50%       25.000000          5.000000
# 75%      106.000000         29.000000
# max    16518.000000       7510.000000

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Game                0.000000
# ReleaseDate         0.000000
# Genre               0.000000
# TotalEarnings       0.000000
# OfflineEarnings     0.000000
# PercentOffline      9.118087
# TotalPlayers        0.000000
# TotalTournaments    0.000000
# dtype: float64

# %%
df['PercentOffline'] = df['PercentOffline'].fillna(df['PercentOffline'].dropna().mean())
df
# Out:
#                                  Game  ReleaseDate                Genre  \
# 0                      Age of Empires         1997             Strategy
# 1                   Age of Empires II         1999             Strategy
# 2                  Age of Empires III         2005             Strategy
# 3                   Age of Empires IV         2021             Strategy
# 4               Age of Empires Online         2011             Strategy
# ..                                ...          ...                  ...
# 664  Guitar Hero III: Legends of Rock         2007  Music / Rhythm Game
# 665           Guitar Hero: World Tour         2008  Music / Rhythm Game
# 666                   Just Dance 2014         2013  Music / Rhythm Game
# 667                              osu!         2007  Music / Rhythm Game
# 668                      Synth Riders         2018  Music / Rhythm Game
#
#      TotalEarnings  OfflineEarnings  PercentOffline  TotalPlayers  \
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Game, ReleaseDate, Genre, TotalEarnings, OfflineEarnings, PercentOffline, TotalPlayers, TotalTournaments]
# Index: []

# %%
df
# Out:
#                                  Game  ReleaseDate                Genre  \
# 0                      Age of Empires         1997             Strategy
# 1                   Age of Empires II         1999             Strategy
# 2                  Age of Empires III         2005             Strategy
# 3                   Age of Empires IV         2021             Strategy
# 4               Age of Empires Online         2011             Strategy
# ..                                ...          ...                  ...
# 664  Guitar Hero III: Legends of Rock         2007  Music / Rhythm Game
# 665           Guitar Hero: World Tour         2008  Music / Rhythm Game
# 666                   Just Dance 2014         2013  Music / Rhythm Game
# 667                              osu!         2007  Music / Rhythm Game
# 668                      Synth Riders         2018  Music / Rhythm Game
#
#      TotalEarnings  OfflineEarnings  PercentOffline  TotalPlayers  \
# ...

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# ReleaseDate                  0.298954
# TotalEarnings               18.834081
# OfflineEarnings             18.983558
# PercentOffline               0.000000
# TotalPlayers                14.648729
# TotalTournaments            16.292975

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# ReleaseDate                  0.298954
# TotalEarnings               18.834081
# OfflineEarnings             18.983558
# PercentOffline               0.000000
# TotalPlayers                14.648729
# TotalTournaments            16.292975

# %%
df['earning_per_offline'] = df['TotalPlayers'] * df['PercentOffline']

df.head()
# Out:
#                     Game  ReleaseDate     Genre  TotalEarnings  \
# 0         Age of Empires         1997  Strategy      736284.75
# 1      Age of Empires II         1999  Strategy     3898508.73
# 2     Age of Empires III         2005  Strategy      122256.72
# 3      Age of Empires IV         2021  Strategy     1190813.44
# 4  Age of Empires Online         2011  Strategy       11462.98
#
#    OfflineEarnings  PercentOffline  TotalPlayers  TotalTournaments  \
# 0        522378.17        0.709478           624               341
# 1       1361409.22        0.349213          2256              1939
# 2         44472.60        0.363764           172               179
# 3        439117.93        0.368755           643               423
# 4           775.00        0.067609            52                68
#
#    earning_per_offline
# 0           442.714559
# 1           787.824118
# 2            62.567417
# 3           237.109206
# 4             3.515665

# %%
df = df.drop(columns=['PercentOffline'])

df.head()
# Out:
#                     Game  ReleaseDate     Genre  TotalEarnings  \
# 0         Age of Empires         1997  Strategy      736284.75
# 1      Age of Empires II         1999  Strategy     3898508.73
# 2     Age of Empires III         2005  Strategy      122256.72
# 3      Age of Empires IV         2021  Strategy     1190813.44
# 4  Age of Empires Online         2011  Strategy       11462.98
#
#    OfflineEarnings  TotalPlayers  TotalTournaments  earning_per_offline
# 0        522378.17           624               341           442.714559
# 1       1361409.22          2256              1939           787.824118
# 2         44472.60           172               179            62.567417
# 3        439117.93           643               423           237.109206
# 4           775.00            52                68             3.515665
